# %% [markdown]
# # Cryptocurrency Prices Data

# %% [markdown]
# This is a dataset of over 50 Cryptocurrencies' historical OHLC (Open High Low Close) data. The date range is from May 2013 to October 2022 on a daily basis. The prices are represented in USD or $. The file format is CSV which is tabular and faster to load.
#
# The data was scraped and cleaned from the Coin Market Cap website using automated scripts.

# %% [markdown]
# Column Description

# %% [markdown]
# open: Opening price on that particular date (UTC time)
#
# high: Highest price hit on that particular date (UTC time)
#
# low: Lowest price hit on that particular date (UTC time)
#
# close: Closing price on that particular date (UTC time)
#
# volume: Quantity of asset bought or sold, displayed in base currency
#
# marketCap: The total value of all the coins that have been mined. It's calculated by multiplying the number of coins in circulation by the current market price of a single coin
#
# timestamp: UTC timestamp of the day considered
#
# crypto_name: Name of the cryptocurrency
#
# date: timestamp converted to date

# %% [markdown]
# # Metadata

# %% [markdown]
# Author Name: Maharshi Pandya
#
# Sources: This data is scraped from the Coin Market Cap website.
#
# Collection Methodology: Using web scraping and Python, this data is collected and stored in CSV file format.

# %% [markdown]
# # Objectives

# %% [markdown]
# Forecasting the high price hit of cryptocurrencies.

# %% [markdown]
# ## Specific Objectives: Specifically, the project will

# %% [markdown]
# Prepare the dataset using various preprocessing tecniques.
#
# Create the machine learning model.
#
# Compare the performance of the machine learning model regression accuracy by using trained data and test data.
#
# Deployed the model that has achieve thee highest accuracy.
#
# Develop the front-end application using Python Flask framework.

# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame

# %%
df=pd.read_csv("dataset.csv")

# %%
df
# Out:
#        Unnamed: 0        open        high         low       close  \
# 0               0  112.900002  118.800003  107.142998  115.910004
# 1               1    3.493130    3.692460    3.346060    3.590890
# 2               2  115.980003  124.663002  106.639999  112.300003
# 3               3    3.594220    3.781020    3.116020    3.371250
# 4               4  112.250000  113.444000   97.699997  111.500000
# ...           ...         ...         ...         ...         ...
# 72941       72941    0.022604    0.022988    0.022197    0.022796
# 72942       72942    1.468244    1.530464    1.435415    1.517878
# 72943       72943    4.950431    5.148565    4.945280    5.117206
# 72944       72944    0.000233    0.000243    0.000226    0.000239
# 72945       72945    0.465490    0.471006    0.453438    0.469033
#
#              volume     marketCap                 timestamp    crypto_name  \
# 0      0.000000e+00  1.288693e+09  2013-05-05T23:59:59.999Z        Bitcoin
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72946 entries, 0 to 72945
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   72946 non-null  int64
#  1   open         72946 non-null  float64
#  2   high         72946 non-null  float64
#  3   low          72946 non-null  float64
#  4   close        72946 non-null  float64
#  5   volume       72946 non-null  float64
#  6   marketCap    72946 non-null  float64
#  7   timestamp    72946 non-null  object
#  8   crypto_name  72946 non-null  object
#  9   date         72946 non-null  object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 5.6+ MB

# %%
len(df)
# Out:
# 72946

# %%
len(df.columns)
# Out:
# 10

# %%
df.shape
# Out:
# (72946, 10)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'open', 'high', 'low', 'close', 'volume', 'marketCap',
#        'timestamp', 'crypto_name', 'date'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# open           float64
# high           float64
# low            float64
# close          float64
# volume         float64
# marketCap      float64
# timestamp       object
# crypto_name     object
# date            object
# dtype: object

# %%
df.describe()
# Out:
#          Unnamed: 0          open          high           low         close  \
# count  72946.000000  72946.000000  7.294600e+04  72946.000000  7.294600e+04
# mean   36472.500000    870.194495  8.964124e+02    844.060640  8.712949e+02
# std    21057.840705   5231.654470  5.398613e+03   5079.389387  5.235508e+03
# min        0.000000      0.000000  1.022100e-10      0.000000  8.292000e-11
# 25%    18236.250000      0.167916  1.767999e-01      0.158630  1.682982e-01
# 50%    36472.500000      1.630666  1.717542e+00      1.541486  1.640219e+00
# 75%    54708.750000     26.070557  2.756868e+01     24.791776  2.625195e+01
# max    72945.000000  67549.735581  1.621883e+05  66458.723733  6.756683e+04
#
#              volume     marketCap
# count  7.294600e+04  7.294600e+04
# mean   2.207607e+09  1.474922e+10
# std    9.617885e+09  7.501159e+10
# min    0.000000e+00  0.000000e+00
# 25%    8.320618e+06  1.860432e+08
# 50%    1.098756e+08  1.268539e+09
# 75%    6.691398e+08  5.118618e+09
# ...

# %%
df.value_counts(subset='Unnamed: 0')
# Out:
# Unnamed: 0
# 0        1
# 48628    1
# 48634    1
# 48633    1
# 48632    1
#         ..
# 24321    1
# 24322    1
# 24323    1
# 24324    1
# 72945    1
# Length: 72946, dtype: int64

# %%
df.value_counts(subset='open')
# Out:
# open
# 1.000000e+00    601
# 1.684200e-10     62
# 1.194400e-10     61
# 1.000010e+00     52
# 1.000100e+00     36
#                ...
# 4.368890e-01      1
# 4.369030e-01      1
# 4.369519e-01      1
# 4.370948e-01      1
# 6.754974e+04      1
# Length: 71771, dtype: int64

# %%
df.value_counts(subset='high')
# Out:
# high
# 1.000000e+00    570
# 1.684200e-10     62
# 1.700500e-10     61
# 1.000010e+00     46
# 1.000200e+00     42
#                ...
# 4.579981e-01      1
# 4.581370e-01      1
# 4.581880e-01      1
# 4.582045e-01      1
# 1.621883e+05      1
# Length: 71769, dtype: int64

# %%
df.value_counts(subset='low')
# Out:
# low
# 1.000000e+00    567
# 1.275000e-10     62
# 1.194400e-10     61
# 1.000010e+00     52
# 9.997000e-01     38
#                ...
# 4.149471e-01      1
# 4.150299e-01      1
# 4.150462e-01      1
# 4.151280e-01      1
# 6.645872e+04      1
# Length: 71801, dtype: int64

# %%
df.value_counts(subset='close')
# Out:
# close
# 1.000000e+00    597
# 1.331600e-10     62
# 1.682300e-10     61
# 1.000010e+00     52
# 1.000100e+00     37
#                ...
# 4.367800e-01      1
# 4.368088e-01      1
# 4.368165e-01      1
# 4.368373e-01      1
# 6.756683e+04      1
# Length: 71763, dtype: int64

# %%
df.value_counts(subset='volume')
# Out:
# volume
# 0.000000e+00    688
# 1.549940e+07      3
# 1.062640e+06      2
# 1.028590e+09      2
# 6.915810e+06      2
#                ...
# 2.404848e+07      1
# 2.405110e+07      1
# 2.405150e+07      1
# 2.405500e+07      1
# 3.509679e+11      1
# Length: 72190, dtype: int64

# %%
df.value_counts(subset='marketCap')
# Out:
# marketCap
# 0.000000e+00    2474
# 4.516000e+05     197
# 2.516000e+05      73
# 1.451600e+06      45
# 6.951591e+06      36
#                 ...
# 4.621238e+08       1
# 4.621669e+08       1
# 4.623451e+08       1
# 4.623827e+08       1
# 1.274831e+12       1
# Length: 69838, dtype: int64

# %%
df.value_counts(subset='timestamp')
# Out:
# timestamp
# 2022-10-23T23:59:59.999Z    56
# 2022-05-31T23:59:59.999Z    55
# 2022-04-24T23:59:59.999Z    55
# 2022-04-25T23:59:59.999Z    55
# 2022-04-26T23:59:59.999Z    55
#                             ..
# 2013-07-08T23:59:59.999Z     2
# 2013-07-09T23:59:59.999Z     2
# 2013-07-10T23:59:59.999Z     2
# 2013-07-11T23:59:59.999Z     2
# 2013-05-05T23:59:59.999Z     2
# Length: 3248, dtype: int64

# %%
df.value_counts(subset='crypto_name')
# Out:
# crypto_name
# Bitcoin                  3248
# Litecoin                 3248
# XRP                      3157
# Dogecoin                 3024
# Monero                   2866
# Stellar                  2791
# Tether                   2582
# Ethereum                 2424
# Ethereum Classic         2072
# Basic Attention Token    1760
# EOS                      1730
# Bitcoin Cash             1708
# BNB                      1706
# TRON                     1656
# Decentraland             1652
# Chainlink                1649
# Cardano                  1638
# Maker                    1605
# Filecoin                 1565
# Theta Network            1530
# Huobi Token              1513
# Ravencoin                1478
# Tezos                    1365
# VeChain                  1332
# Quant                    1325
# USD Coin                 1266
# Cronos                   1199
# Wrapped Bitcoin          1152
# Cosmos                   1109
# Polygon                  1064
# ...

# %%
df.value_counts(subset='date')
# Out:
# date
# 2022-10-23    56
# 2022-05-31    55
# 2022-04-24    55
# 2022-04-25    55
# 2022-04-26    55
#               ..
# 2013-07-08     2
# 2013-07-09     2
# 2013-07-10     2
# 2013-07-11     2
# 2013-05-05     2
# Length: 3248, dtype: int64

# %%
df.memory_usage(index=True)
# Out:
# Index             128
# Unnamed: 0     583568
# open           583568
# high           583568
# low            583568
# close          583568
# volume         583568
# marketCap      583568
# timestamp      583568
# crypto_name    583568
# date           583568
# dtype: int64

# %%
df.isna().sum()
#no null values
# Out:
# Unnamed: 0     0
# open           0
# high           0
# low            0
# close          0
# volume         0
# marketCap      0
# timestamp      0
# crypto_name    0
# date           0
# dtype: int64

# %% [markdown]
# ## Preprocessing (Outlier Treatment using Interquartile Range Method by Deletion)

# %%
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np

# %%
df.drop("Unnamed: 0", axis=1, inplace= True)
df
# Out:
#              open        high         low       close        volume  \
# 0      112.900002  118.800003  107.142998  115.910004  0.000000e+00
# 1        3.493130    3.692460    3.346060    3.590890  0.000000e+00
# 2      115.980003  124.663002  106.639999  112.300003  0.000000e+00
# 3        3.594220    3.781020    3.116020    3.371250  0.000000e+00
# 4      112.250000  113.444000   97.699997  111.500000  0.000000e+00
# ...           ...         ...         ...         ...           ...
# 72941    0.022604    0.022988    0.022197    0.022796  4.040134e+07
# 72942    1.468244    1.530464    1.435415    1.517878  2.844351e+07
# 72943    4.950431    5.148565    4.945280    5.117206  1.069497e+08
# 72944    0.000233    0.000243    0.000226    0.000239  2.143268e+08
# 72945    0.465490    0.471006    0.453438    0.469033  9.509743e+08
#
#           marketCap                 timestamp    crypto_name        date
# 0      1.288693e+09  2013-05-05T23:59:59.999Z        Bitcoin  2013-05-05
# ...

# %%
df.dtypes
# Out:
# open           float64
# high           float64
# low            float64
# close          float64
# volume         float64
# marketCap      float64
# timestamp       object
# crypto_name     object
# date            object
# dtype: object

# %% [markdown]
# ### "high" column outlier Treatment

# %%
sn.distplot(df.high)
plt.show()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
IQR=np.percentile(df.high, 75) - np.percentile(df.high, 25)
lower=max(0, np.percentile(df.high, 25) - 1.5 * IQR)
upper=np.percentile(df.high, 75) + 1.5 * IQR
print("Range is between ",lower, "and", upper)
# Out:
# Range is between  0 and 68.6564923596625

# %%
#Outlier Detection
df[(df.high < lower) | (df.high > upper)]
# Out:
#                open          high           low         close        volume  \
# 0        112.900002    118.800003    107.142998    115.910004  0.000000e+00
# 2        115.980003    124.663002    106.639999    112.300003  0.000000e+00
# 4        112.250000    113.444000     97.699997    111.500000  0.000000e+00
# 7        109.599998    115.779999    109.599998    113.566002  0.000000e+00
# 9        113.199997    113.459999    109.260002    112.669998  0.000000e+00
# ...             ...           ...           ...           ...           ...
# 72912  19207.734651  19646.651542  19124.196965  19567.007398  2.212879e+10
# 72921   1314.249452   1367.760725   1302.908759   1363.447058  9.909511e+09
# 72927    179.192399    179.759283    170.586636    175.486745  8.932977e+07
# 72933    142.805842    144.903386    142.196376    144.488086  5.901019e+07
# 72934    996.685592   1002.233274    934.022119    978.696269  4.195108e+07
#
# ...

# %%
#Treatment by deletion
df1 = df[(df.high >= lower) & (df.high <= upper)]
df1
# Out:
#            open      high       low     close        volume     marketCap  \
# 1      3.493130  3.692460  3.346060  3.590890  0.000000e+00  6.229819e+07
# 3      3.594220  3.781020  3.116020  3.371250  0.000000e+00  5.859436e+07
# 5      3.370870  3.406720  2.939790  3.332740  0.000000e+00  5.805127e+07
# 6      3.283620  3.491120  3.283620  3.409240  0.000000e+00  5.950822e+07
# 8      3.399400  3.441690  3.294850  3.416150  0.000000e+00  5.975557e+07
# ...         ...       ...       ...       ...           ...           ...
# 72941  0.022604  0.022988  0.022197  0.022796  4.040134e+07  1.652957e+09
# 72942  1.468244  1.530464  1.435415  1.517878  2.844351e+07  1.572825e+09
# 72943  4.950431  5.148565  4.945280  5.117206  1.069497e+08  1.559551e+09
# 72944  0.000233  0.000243  0.000226  0.000239  2.143268e+08  1.576291e+09
# 72945  0.465490  0.471006  0.453438  0.469033  9.509743e+08  2.339868e+10
#
#                       timestamp    crypto_name        date
# ...

# %%
df1.shape
# Out:
# (58957, 9)

# %%
sn.distplot(df1.high)
plt.show()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### "open" column outlier treatment

# %%
sn.distplot(df1.open)
plt.show()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
IQR=np.percentile(df1.open, 75) - np.percentile(df1.open, 25)
lower=max(0, np.percentile(df1.open, 25) - 1.5 * IQR)
upper=np.percentile(df1.open, 75) + 1.5 * IQR
print("Range is between ",lower, "and", upper)
# Out:
# Range is between  0 and 10.93001126175

# %%
#Outlier Detection
df1[(df1.open < lower) | (df1.open > upper)]
# Out:
#             open       high        low      close        volume     marketCap  \
# 525    12.376000  20.353201  11.813800  20.353201  0.000000e+00  4.756531e+08
# 527    19.909000  39.036400  19.035500  39.036400  0.000000e+00  9.134417e+08
# 532    38.991299  53.146999  36.863400  43.393501  0.000000e+00  1.016868e+09
# 533    44.368801  47.939800  28.608400  37.739899  0.000000e+00  8.856400e+08
# 537    36.941700  43.779301  35.007099  40.467499  0.000000e+00  9.509151e+08
# ...          ...        ...        ...        ...           ...           ...
# 72922  23.235518  23.554784  22.762526  23.407029  3.524683e+08  3.219062e+09
# 72923  28.013676  29.331540  27.857959  29.270071  6.331571e+08  1.048962e+10
# 72930  15.639873  15.956684  15.583392  15.956684  1.751313e+07  9.574010e+08
# 72935  52.181555  53.950366  51.944883  53.950366  3.446915e+08  3.854806e+09
# 72939  22.580207  23.184871  22.421821  23.147571  3.469170e+07  3.084676e+09
#
# ...

# %%
#Treatment by deletion
df2 = df1[(df1.open >= lower) & (df1.open <= upper)]
df2
# Out:
#            open      high       low     close        volume     marketCap  \
# 1      3.493130  3.692460  3.346060  3.590890  0.000000e+00  6.229819e+07
# 3      3.594220  3.781020  3.116020  3.371250  0.000000e+00  5.859436e+07
# 5      3.370870  3.406720  2.939790  3.332740  0.000000e+00  5.805127e+07
# 6      3.283620  3.491120  3.283620  3.409240  0.000000e+00  5.950822e+07
# 8      3.399400  3.441690  3.294850  3.416150  0.000000e+00  5.975557e+07
# ...         ...       ...       ...       ...           ...           ...
# 72941  0.022604  0.022988  0.022197  0.022796  4.040134e+07  1.652957e+09
# 72942  1.468244  1.530464  1.435415  1.517878  2.844351e+07  1.572825e+09
# 72943  4.950431  5.148565  4.945280  5.117206  1.069497e+08  1.559551e+09
# 72944  0.000233  0.000243  0.000226  0.000239  2.143268e+08  1.576291e+09
# 72945  0.465490  0.471006  0.453438  0.469033  9.509743e+08  2.339868e+10
#
#                       timestamp    crypto_name        date
# ...

# %%
df2.shape
# Out:
# (50154, 9)

# %%
sn.distplot(df2.open)
plt.show()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### "low" column outlier treatment

# %%
sn.distplot(df2.low)
plt.show()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
IQR=np.percentile(df2.low, 75) - np.percentile(df2.low, 25)
lower=max(0, np.percentile(df2.low, 25) - 1.5 * IQR)
upper=np.percentile(df2.low, 75) + 1.5 * IQR
print("Range is between ",lower, "and", upper)
# Out:
# Range is between  0 and 4.777741498999999

# %%
#outlier detection
df2[(df2.low < lower) | (df2.low > upper)]
# Out:
#             open       high        low      close        volume     marketCap  \
# 504     9.422690  10.274600   6.658730   8.026700  0.000000e+00  1.859023e+08
# 506     7.964560   8.212100   6.000260   7.976200  0.000000e+00  1.849776e+08
# 510     8.011430   9.514830   7.793420   9.348240  0.000000e+00  2.170768e+08
# 512     9.362230  10.348500   8.812630  10.129000  0.000000e+00  2.354931e+08
# 516    10.117000  11.082500  10.046600  10.611000  0.000000e+00  2.470357e+08
# ...          ...        ...        ...        ...           ...           ...
# 72916   8.939706  10.246318   8.930175   9.768685  1.563615e+09  1.269929e+09
# 72929   5.847780   5.968046   5.776710   5.960239  2.014905e+08  6.731207e+09
# 72936   4.905588   5.029796   4.813594   5.021913  2.784509e+07  1.350319e+09
# 72937   8.848058   9.121299   8.324531   8.726945  5.018698e+07  1.338344e+09
# 72943   4.950431   5.148565   4.945280   5.117206  1.069497e+08  1.559551e+09
#
# ...

# %%
#Treatment by deletion
df3 = df2[(df2.low >= lower) & (df2.low <= upper)]
df3
# Out:
#            open      high       low     close        volume     marketCap  \
# 1      3.493130  3.692460  3.346060  3.590890  0.000000e+00  6.229819e+07
# 3      3.594220  3.781020  3.116020  3.371250  0.000000e+00  5.859436e+07
# 5      3.370870  3.406720  2.939790  3.332740  0.000000e+00  5.805127e+07
# 6      3.283620  3.491120  3.283620  3.409240  0.000000e+00  5.950822e+07
# 8      3.399400  3.441690  3.294850  3.416150  0.000000e+00  5.975557e+07
# ...         ...       ...       ...       ...           ...           ...
# 72940  1.383998  1.406040  1.354278  1.404507  4.750240e+06  1.715466e+09
# 72941  0.022604  0.022988  0.022197  0.022796  4.040134e+07  1.652957e+09
# 72942  1.468244  1.530464  1.435415  1.517878  2.844351e+07  1.572825e+09
# 72944  0.000233  0.000243  0.000226  0.000239  2.143268e+08  1.576291e+09
# 72945  0.465490  0.471006  0.453438  0.469033  9.509743e+08  2.339868e+10
#
#                       timestamp    crypto_name        date
# ...

# %%
df3.shape
# Out:
# (45324, 9)

# %%
sn.distplot(df3.low)
plt.show()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### "close" column outlier treatment

# %%
sn.distplot(df3.close)
plt.show()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
IQR=np.percentile(df3.close, 75) - np.percentile(df3.close, 25)
lower=max(0, np.percentile(df3.close, 25) - 1.5 * IQR)
upper=np.percentile(df3.close, 75) + 1.5 * IQR
print("Range is between ",lower, "and", upper)
# Out:
# Range is between  0 and 2.6486080296875

# %%
df3[(df3.close < lower) | (df3.close > upper)]
# Out:
#            open      high       low     close        volume     marketCap  \
# 1      3.493130  3.692460  3.346060  3.590890  0.000000e+00  6.229819e+07
# 3      3.594220  3.781020  3.116020  3.371250  0.000000e+00  5.859436e+07
# 5      3.370870  3.406720  2.939790  3.332740  0.000000e+00  5.805127e+07
# 6      3.283620  3.491120  3.283620  3.409240  0.000000e+00  5.950822e+07
# 8      3.399400  3.441690  3.294850  3.416150  0.000000e+00  5.975557e+07
# ...         ...       ...       ...       ...           ...           ...
# 72841  4.457581  4.501500  4.456526  4.489012  2.994592e+06  4.282312e+09
# 72866  2.919815  3.034788  2.919815  3.002484  1.041332e+08  2.437739e+09
# 72917  4.473566  4.669737  4.447018  4.634309  1.038651e+08  1.422154e+09
# 72925  4.097667  4.166921  4.083898  4.158306  2.578287e+06  3.966833e+09
# 72931  2.918992  2.997398  2.852219  2.979279  1.470331e+08  2.426430e+09
#
#                       timestamp    crypto_name        date
# ...

# %%
#Treatment by deletion
df4 =df3 [(df3.close >= lower) & (df3.close <= upper)]
df4
# Out:
#            open      high       low     close        volume     marketCap  \
# 67     2.779140  2.793680  2.511510  2.602410  0.000000e+00  4.774005e+07
# 69     2.604060  2.657480  2.536210  2.562380  0.000000e+00  4.708887e+07
# 70     2.552730  2.587880  2.072670  2.383000  0.000000e+00  4.385829e+07
# 72     2.384380  2.580290  2.261240  2.487530  0.000000e+00  4.585340e+07
# 74     2.492840  2.498870  2.181020  2.397980  0.000000e+00  4.427032e+07
# ...         ...       ...       ...       ...           ...           ...
# 72940  1.383998  1.406040  1.354278  1.404507  4.750240e+06  1.715466e+09
# 72941  0.022604  0.022988  0.022197  0.022796  4.040134e+07  1.652957e+09
# 72942  1.468244  1.530464  1.435415  1.517878  2.844351e+07  1.572825e+09
# 72944  0.000233  0.000243  0.000226  0.000239  2.143268e+08  1.576291e+09
# 72945  0.465490  0.471006  0.453438  0.469033  9.509743e+08  2.339868e+10
#
#                       timestamp    crypto_name        date
# ...

# %%
df4.shape
# Out:
# (39262, 9)

# %%
sn.distplot(df4.close)
plt.show()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df4
# Out:
#            open      high       low     close        volume     marketCap  \
# 67     2.779140  2.793680  2.511510  2.602410  0.000000e+00  4.774005e+07
# 69     2.604060  2.657480  2.536210  2.562380  0.000000e+00  4.708887e+07
# 70     2.552730  2.587880  2.072670  2.383000  0.000000e+00  4.385829e+07
# 72     2.384380  2.580290  2.261240  2.487530  0.000000e+00  4.585340e+07
# 74     2.492840  2.498870  2.181020  2.397980  0.000000e+00  4.427032e+07
# ...         ...       ...       ...       ...           ...           ...
# 72940  1.383998  1.406040  1.354278  1.404507  4.750240e+06  1.715466e+09
# 72941  0.022604  0.022988  0.022197  0.022796  4.040134e+07  1.652957e+09
# 72942  1.468244  1.530464  1.435415  1.517878  2.844351e+07  1.572825e+09
# 72944  0.000233  0.000243  0.000226  0.000239  2.143268e+08  1.576291e+09
# 72945  0.465490  0.471006  0.453438  0.469033  9.509743e+08  2.339868e+10
#
#                       timestamp    crypto_name        date
# ...

# %%
df4.shape
# Out:
# (39262, 9)

# %%
first_column = df4.pop('high')
df4.insert(0, 'high', first_column)
df4
# Out:
#            high      open       low     close        volume     marketCap  \
# 67     2.793680  2.779140  2.511510  2.602410  0.000000e+00  4.774005e+07
# 69     2.657480  2.604060  2.536210  2.562380  0.000000e+00  4.708887e+07
# 70     2.587880  2.552730  2.072670  2.383000  0.000000e+00  4.385829e+07
# 72     2.580290  2.384380  2.261240  2.487530  0.000000e+00  4.585340e+07
# 74     2.498870  2.492840  2.181020  2.397980  0.000000e+00  4.427032e+07
# ...         ...       ...       ...       ...           ...           ...
# 72940  1.406040  1.383998  1.354278  1.404507  4.750240e+06  1.715466e+09
# 72941  0.022988  0.022604  0.022197  0.022796  4.040134e+07  1.652957e+09
# 72942  1.530464  1.468244  1.435415  1.517878  2.844351e+07  1.572825e+09
# 72944  0.000243  0.000233  0.000226  0.000239  2.143268e+08  1.576291e+09
# 72945  0.471006  0.465490  0.453438  0.469033  9.509743e+08  2.339868e+10
#
#                       timestamp    crypto_name        date
# ...

# %%
features = df4.columns[1:4]
features
# Out:
# Index(['open', 'low', 'close'], dtype='object')

# %%
target = df4.columns[:1]
target
# Out:
# Index(['high'], dtype='object')

# %% [markdown]
# # Pandas Profiling

# %%
import pandas_profiling as pp

# %%
profile=pp.ProfileReport(df4)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv3.5.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-12-15 08:54:14.936243&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # Scaling (Normalize or Standardize data)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# %%
df4.sample(5)
# Out:
#            high      open       low     close        volume     marketCap  \
# 38632  2.760557  2.758748  2.380607  2.518277  2.193951e+08  4.802062e+08
# 32570  0.269559  0.267209  0.258938  0.262855  5.001248e+05  7.564073e+07
# 10650  0.002543  0.002064  0.002049  0.002543  1.668140e+07  2.820460e+08
# 37796  0.004032  0.003964  0.003884  0.003936  1.211131e+08  2.182695e+08
# 32783  0.053336  0.053072  0.051145  0.051673  1.787191e+08  1.036298e+09
#
#                       timestamp    crypto_name        date
# 38632  2020-05-10T23:59:59.999Z         Cosmos  2020-05-10
# 32570  2019-12-09T23:59:59.999Z  Terra Classic  2019-12-09
# 10650  2017-09-01T23:59:59.999Z       Dogecoin  2017-09-01
# 37796  2020-04-19T23:59:59.999Z        VeChain  2020-04-19
# 32783  2019-12-14T23:59:59.999Z        Stellar  2019-12-14

# %%
scaler_minmax=MinMaxScaler()
scaler_std=StandardScaler()
scaler_robust=RobustScaler()

# %%
df4_scaled1=DataFrame(scaler_minmax.fit_transform(df4[features]),columns=features)
df4_scaled2=DataFrame(scaler_std.fit_transform(df4[features]),columns=features)
df4_scaled3=DataFrame(scaler_robust.fit_transform(df4[features]),columns=features)

# %%
#plot histogram of raw data
df4.hist(figsize=(10,9),ec="k")
plt.title('Raw Dataset')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plot histogram for the scaled data using MinMaxScaler
df4_scaled1.hist(figsize=(10,9))
plt.title('Dataset after MinMax scaling')
plt.tight_layout()
plt.show()

# %%
#plot histogram for the scaled data using MinMaxScaler
df4_scaled2.hist(figsize=(10,8),ec="k")
plt.title('Dataset after Standard Scaling')
plt.tight_layout()
plt.show()

# %%
df4_scaled3.hist(figsize=(10,8),ec="k")
plt.title('Dataset after RobustScaling')
plt.tight_layout()
plt.show()

# %%
df4_scaled1.head()
# Out:
#        open       low     close
# 0  0.697610  0.952962  0.982722
# 1  0.653662  0.962334  0.967606
# 2  0.640777  0.786450  0.899869
# 3  0.598519  0.858000  0.939341
# 4  0.625744  0.827562  0.905525

# %%
df4.head()
# Out:
#        high     open      low    close  volume     marketCap  \
# 67  2.79368  2.77914  2.51151  2.60241     0.0  4.774005e+07
# 69  2.65748  2.60406  2.53621  2.56238     0.0  4.708887e+07
# 70  2.58788  2.55273  2.07267  2.38300     0.0  4.385829e+07
# 72  2.58029  2.38438  2.26124  2.48753     0.0  4.585340e+07
# 74  2.49887  2.49284  2.18102  2.39798     0.0  4.427032e+07
#
#                    timestamp crypto_name        date
# 67  2013-06-07T23:59:59.999Z    Litecoin  2013-06-07
# 69  2013-06-08T23:59:59.999Z    Litecoin  2013-06-08
# 70  2013-06-09T23:59:59.999Z    Litecoin  2013-06-09
# 72  2013-06-10T23:59:59.999Z    Litecoin  2013-06-10
# 74  2013-06-11T23:59:59.999Z    Litecoin  2013-06-11

# %%
target_data=df4['high']
target_data.head(10)
# Out:
# 67    2.79368
# 69    2.65748
# 70    2.58788
# 72    2.58029
# 74    2.49887
# 76    2.45422
# 78    2.48628
# 80    2.28874
# 82    2.20847
# 84    2.15022
# Name: high, dtype: float64

# %%
scaled_data=pd.concat([df4_scaled1,target_data],axis=1)
scaled_data.head(200)
# Out:
#          open       low     close      high
# 0    0.697610  0.952962  0.982722       NaN
# 1    0.653662  0.962334  0.967606       NaN
# 2    0.640777  0.786450  0.899869       NaN
# 3    0.598519  0.858000  0.939341       NaN
# 4    0.625744  0.827562  0.905525       NaN
# ..        ...       ...       ...       ...
# 195  0.006998  0.010563  0.010944  0.004424
# 196  0.007346  0.010763  0.011701       NaN
# 197  0.007756  0.011511  0.014495  0.004367
# 198  0.009830  0.014859  0.019446       NaN
# 199  0.013149  0.019784  0.020864       NaN
#
# [200 rows x 4 columns]

# %%
df4.isna().sum()
# Out:
# high           0
# open           0
# low            0
# close          0
# volume         0
# marketCap      0
# timestamp      0
# crypto_name    0
# date           0
# dtype: int64

# %%
df4.shape
# Out:
# (39262, 9)

# %%
scaled_data.isnull().sum()
# Out:
# open     15742
# low      15742
# close    15742
# high     15742
# dtype: int64

# %%
nw_scaled = scaled_data.dropna()
nw_scaled
# Out:
#            open       low     close      high
# 67     0.685579  0.993429  0.998469  2.793680
# 69     0.001578  0.002280  0.002397  2.657480
# 70     0.001590  0.002397  0.002459  2.587880
# 72     0.668306  0.957709  0.959820  2.580290
# 74     0.001594  0.002409  0.002444  2.498870
# ...         ...       ...       ...       ...
# 39254  0.208939  0.312090  0.339797  1.006599
# 39256  0.014993  0.022217  0.022874  0.079473
# 39257  0.347406  0.513864  0.530370  2.543624
# 39258  0.005674  0.008422  0.008608  1.001710
# 39260  0.000058  0.000086  0.000090  0.021618
#
# [23520 rows x 4 columns]

# %%
nw_scaled.isna().sum()
# Out:
# open     0
# low      0
# close    0
# high     0
# dtype: int64

# %%
nw_scaled
# Out:
#            open       low     close      high
# 67     0.685579  0.993429  0.998469  2.793680
# 69     0.001578  0.002280  0.002397  2.657480
# 70     0.001590  0.002397  0.002459  2.587880
# 72     0.668306  0.957709  0.959820  2.580290
# 74     0.001594  0.002409  0.002444  2.498870
# ...         ...       ...       ...       ...
# 39254  0.208939  0.312090  0.339797  1.006599
# 39256  0.014993  0.022217  0.022874  0.079473
# 39257  0.347406  0.513864  0.530370  2.543624
# 39258  0.005674  0.008422  0.008608  1.001710
# 39260  0.000058  0.000086  0.000090  0.021618
#
# [23520 rows x 4 columns]

# %% [markdown]
# # Split Data to train and test dataset

# %%
from sklearn.model_selection import train_test_split
train, test=train_test_split(nw_scaled,test_size=0.2,random_state=42)
train.sample(5)
# Out:
#            open       low     close      high
# 6506   0.000454  0.000668  0.000676  0.001967
# 38598  0.210604  0.317479  0.348772  0.625429
# 10371  0.334748  0.502152  0.517815  1.866400
# 22391  0.000991  0.001445  0.001472  0.025251
# 37692  0.042054  0.062620  0.063954  0.006879

# %% [markdown]
# # 3-4. Spot check algorithms and show evaluation metrics (RSME)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import ExtraTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score,KFold
from sklearn.metrics import mean_squared_error
from numpy import mean
from numpy import std
import math

# %%
#Load the dataset
X_train=train[features]
y_train=train[target]
X_test=test[features]
y_test=test[target]

#define the models
models=dict()
models['svml'] = SVR(kernel='linear')
models['svmp'] = SVR(kernel='poly')
models['svmp'] = SVR(kernel='poly')
models['cart'] = DecisionTreeRegressor()
models['lr'] = LinearRegression()
n_trees=100 #for ensembles

models['ada'] = AdaBoostRegressor(n_estimators=n_trees)
models['bag'] = BaggingRegressor(n_estimators=n_trees)
models['rt'] = RandomForestRegressor(n_estimators=n_trees)
models['et'] = ExtraTreesRegressor(n_estimators=n_trees)
models['gb'] = GradientBoostingRegressor(n_estimators=n_trees)

#check model performance using cross validation
for name, model in models.items():
    #evaluate the model using 5-fold cross validation
    cv=KFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X_train, y_train, scoring='neg_root_mean_squared_error', cv=cv, n_jobs=-1, error_score='raise')
    print(name, '\n5-Fold Validation Scores:\n', scores)
    print('Cross Validation Average Score and StDev: %.3f (%.3f)\n' % (mean(scores), std(scores)))
# Out:
# svml
# 5-Fold Validation Scores:
#  [-0.72967258 -0.97277432 -0.72642514 -0.721682   -0.72844946]
# Cross Validation Average Score and StDev: -0.776 (0.099)
#
# svmp
# 5-Fold Validation Scores:
#  [-0.72964587 -0.97269754 -0.72632913 -0.72147784 -0.72848111]
# Cross Validation Average Score and StDev: -0.776 (0.099)
#
# cart
# 5-Fold Validation Scores:
#  [-0.9423281  -1.1343343  -1.08488809 -1.27779082 -0.92943253]
# Cross Validation Average Score and StDev: -1.074 (0.129)
#
# lr
# 5-Fold Validation Scores:
#  [-0.65433042 -0.90799306 -0.65202921 -0.65028351 -0.65523673]
# Cross Validation Average Score and StDev: -0.704 (0.102)
#
# ada
# 5-Fold Validation Scores:
#  [-0.79249003 -0.97032883 -0.82561185 -0.99051497 -0.6927382 ]
# Cross Validation Average Score and StDev: -0.854 (0.112)
#
# bag
# 5-Fold Validation Scores:
#  [-0.71033172 -0.94778628 -0.72797128 -0.78343469 -0.69985858]
# Cross Validation Average Score and StDev: -0.774 (0.092)
#
# rt
# 5-Fold Validation Scores:
# ...

# %% [markdown]
# # Train the models

# %%
results=dict()
for name, model in models.items():
    model.fit(X_train,y_train)
    predicted=model.predict(X_test)
    rmse=mean_squared_error(predicted,y_test, squared=False)
    print('[',name,'] Root Mean Squared Error (RMSE) is ', rmse)
    results[name]=rmse
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [ svml ] Root Mean Squared Error (RMSE) is  0.725734877026609
# C:\Users\Acer\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [ svmp ] Root Mean Squared Error (RMSE) is  0.7257400016281127
# [ cart ] Root Mean Squared Error (RMSE) is  0.9260547910188904
# [ lr ] Root Mean Squared Error (RMSE) is  0.652021183725927
# ...

# %%
plt.plot(results.keys(),results.values(), 'o')
plt.title('RMSE estimates for ML Algorithms')
plt.xlabel('Algorithms')
plt.ylabel('RMSE Scores')
plt.show()

# %% [markdown]
# # Deploy trained model

# %%
import pickle
pickle.dump(models['lr'], open('model.pkl','wb'))

# %% [markdown]
# # Batch predictions

# %%
test_model = pickle.load(open('model.pkl', 'rb'))

# %%
new_Xdata=X_test.sample(10)
new_ydata=y_test.loc[new_Xdata.index.values] 
print(new_Xdata)
print(new_ydata)
# Out:
#            open       low     close
# 26649  0.017841  0.026870  0.026870
# 33796  0.313306  0.428066  0.429487
# 22099  0.007780  0.011520  0.011597
# 26905  0.064348  0.096125  0.096793
# 4429   0.001649  0.002472  0.002469
# 3333   0.000038  0.000053  0.000054
# 10070  0.033290  0.048683  0.049302
# 29186  0.009760  0.014436  0.023192
# 21375  0.002633  0.003949  0.004468
# 37134  0.015186  0.022618  0.023067
#            high
# 26649  1.013515
# 33796  1.009737
# 22099  2.272344
# 26905  0.049442
# 4429   0.002124
# 3333   1.000000
# 10070  0.102722
# 29186  0.006755
# 21375  1.117796
# 37134  0.162593

# %%
new_ydata.values
# Out:
# array([[1.01351548e+00],
#        [1.00973740e+00],
#        [2.27234389e+00],
#        [4.94422860e-02],
#        [2.12353002e-03],
#        [1.00000000e+00],
#        [1.02721997e-01],
#        [6.75456526e-03],
#        [1.11779645e+00],
#        [1.62593278e-01]])

# %%
pred=test_model.predict(new_Xdata)
print(pred)
# Out:
# [[0.48661629]
#  [0.45929521]
#  [0.48702026]
#  [0.48418571]
#  [0.48736552]
#  [0.48744262]
#  [0.48542556]
#  [0.48658602]
#  [0.48729909]
#  [0.48664497]]

# %%
rmse=mean_squared_error(pred,new_ydata, squared=False)
print('Root Mean Squared Error is ', rmse)
# Out:
# Root Mean Squared Error is  0.791852589527348
